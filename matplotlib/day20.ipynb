# %% [markdown]
#  Day 20 - Lets goooo

# %% [markdown]
# Just ignoring the minor breakdowns hehe

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
a = np.random.rand(100, 2) 
b = np.random.rand(100, 2) 
plt.scatter(a[:, 0], a[:, 1], c='blue', label='Group A')
plt.scatter(b[:, 0], b[:, 1], c='red', label='Group B')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot of Two Groups')
plt.legend()
plt.show()
